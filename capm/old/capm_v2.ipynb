# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import warnings
import quandl

# %% [markdown]
# # Pulling from Quandl

# %%
quandl.ApiConfig.api_key = '_ax8TyabndbbntPNa6JE'

# %%
df = pd.read_csv("data/dax.csv", index_col="Date")

# %%
df
# Out:
#             1COV_X   ADS_X   ALV_X   BAS_X  BAYN_X  BEI_X   BMW_X  CON_X  \
# Date
# 2000-01-03     NaN   71.70     NaN     NaN     NaN    NaN     NaN    NaN
# 2000-01-04     NaN   70.00     NaN     NaN     NaN    NaN     NaN    NaN
# 2000-01-05     NaN   70.00     NaN     NaN     NaN    NaN     NaN    NaN
# 2000-01-06     NaN   73.00     NaN     NaN     NaN    NaN     NaN    NaN
# 2000-01-07     NaN   72.00     NaN     NaN     NaN    NaN     NaN    NaN
# 2000-01-10     NaN   73.09     NaN     NaN     NaN    NaN     NaN    NaN
# 2000-01-11     NaN   72.41     NaN     NaN     NaN    NaN     NaN    NaN
# 2000-01-12     NaN   72.00     NaN     NaN     NaN    NaN     NaN    NaN
# 2000-01-13     NaN   69.85     NaN     NaN     NaN    NaN     NaN    NaN
# 2000-01-14     NaN   67.35     NaN     NaN     NaN    NaN     NaN    NaN
# 2000-01-17     NaN   68.00     NaN     NaN     NaN    NaN     NaN    NaN
# 2000-01-18     NaN   68.00  359.23  47.950   45.10  68.00  27.000  18.20
# ...

# %% [markdown]
# # Compute the Beta

# %%
x = df['1COV_X']
y = df['Index']

# %%
x_2016 = x['2016-01-04':'2020-05-20']
y_2016 = y['2016-01-04':'2020-05-20']

# %%
print(x_2016.isnull().sum())
print(y_2016.isnull().sum())
# Out:
# 13
# 12

# %%
y_2016[y_2016.isnull()]
# Out:
# Date
# 2016-03-28   NaN
# 2016-05-16   NaN
# 2016-10-03   NaN
# 2016-12-26   NaN
# 2017-04-14   NaN
# 2017-04-17   NaN
# 2017-05-01   NaN
# 2017-06-05   NaN
# 2017-10-03   NaN
# 2017-10-31   NaN
# 2017-12-26   NaN
# 2018-05-21   NaN
# Name: Index, dtype: float64

# %%
x_2016[x_2016.isnull()]
# Out:
# Date
# 2016-03-28   NaN
# 2016-05-16   NaN
# 2016-10-03   NaN
# 2016-12-26   NaN
# 2017-04-14   NaN
# 2017-04-17   NaN
# 2017-05-01   NaN
# 2017-06-05   NaN
# 2017-10-03   NaN
# 2017-10-31   NaN
# 2017-12-26   NaN
# 2018-05-21   NaN
# 2019-01-16   NaN
# Name: 1COV_X, dtype: float64

# %%
y_2016['2019-01-16']
# Out:
# 10931.240234

# %%
y_2016.drop('2019-01-16', axis=0, inplace=True)

# %%
x_2016.dropna(inplace=True)
y_2016.dropna(inplace=True)

# %%
print(y_2016.size)
print(x_2016.size)
# Out:
# 1105
# 1105

# %%
np.cov(x_2016,y_2016)
# Out:
# array([[3.30206318e+02, 1.28721503e+04],
#        [1.28721503e+04, 1.32071799e+06]])

# %%
print(np.cov(x_2016,y_2016)[0][1])
print(np.cov(x_2016,y_2016)[1][1])
# Out:
# 12872.150293227614
# 1320717.990214977

# %%
beta = np.cov(x_2016,y_2016)[0][1]/np.cov(x_2016,y_2016)[1][1]
print(beta)
# Out:
# 0.009746327670703098

# %% [markdown]
# # CAPM for May

# %%
x_may_return = (x_2016['2020-05-20']/x_2016['2020-04-30'])-1
x_may_return
# Out:
# 0.02933507170795302

# %%
may_risk_free = 0.05

# %%
alpha = may_risk_free * beta * (x_may_return - may_risk_free)
alpha
# Out:
# -1.0070358121293642e-05

# %% [markdown]
# # Experimental

# %%
df
